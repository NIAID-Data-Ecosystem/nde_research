# %% [markdown]
# # Similarities between combinations -- Lyssna tests

# %% [markdown]
# ## 1. Data import

# %%
import os
import pandas as pd

# %%
script_path = os.getcwd()
datapath = os.path.join(script_path,'data')

# %%
most_likely = pd.read_csv(os.path.join(datapath,'most_likely.tsv'),delimiter='\t',header=0)
most_likely
# Out:
#      Unnamed: 0  round  test                   search term              scope  \
# 0             0      1     1                     influenza         very broad
# 1             2      1     1                    long covid              broad
# 2             4      1     1          malaria therapeutics      very specific
# 3             6      1     2                        asthma         very broad
# 4             8      1     2   naegleria fowleri infection      very specific
# ..          ...    ...   ...                           ...                ...
# 367         734      4     5  plasmacytoid dendritic cells  somewhat specific
# 368         736      4     5          tuberculin skin test  somewhat specific
# 369         738      4     6                           hiv         very broad
# 370         740      4     6                     influenza         very broad
# 371         742      4     6                 mycobacterium         very broad
#
#                       domain test type selection  participants  selection time
# 0         Infectious Disease         M        c1           2.0            34.0
# 1         Infectious Disease         M        c3           2.0           107.0
# 2         Infectious Disease         M        c2           2.0            31.0
# 3                    Allergy         M        c4           3.0            56.0
# 4         Infectious Disease         M       c11           3.0            23.0
# ..                       ...       ...       ...           ...             ...
# 367               Cell types         M        c1           0.0             NaN
# 368  Experimental techniques         M       c15           0.0             NaN
# 369       Infectious Disease         M       c14           1.0            56.0
# 370       Infectious Disease         M        c3           0.0             NaN
# 371       Infectious Disease         M       c14           1.0            14.0
#
# [372 rows x 10 columns]

# %%
most_likely['search term'].unique()
# Out:
# array(['influenza', 'long covid', 'malaria therapeutics', 'asthma',
#        'naegleria fowleri infection', 'zika microcephaly',
#        'allergen skin prick test', 'allergy treatment',
#        'sublingual immunotherapy', 'AIDS', 'immunotherapeutics',
#        't-cell function', "addison's disease", 'cancer',
#        'myocardial infarction', 'dendritic cells', 'mast cells',
#        'rational cancer drug design', 'metabolomics', 'pinealocyte',
#        'plasmacytoid dendritic cells', 'gwas', 'mycobacterium',
#        'tuberculin skin test', 'hiv'], dtype=object)

# %% [markdown]
# ## 2. Data wrangling

# %%
# Remove unneeded columns
most_likely.drop(columns = ['Unnamed: 0', 'scope', 'participants', 'selection time'], inplace = True)
most_likely
# Out:
#      round  test                   search term                   domain  \
# 0        1     1                     influenza       Infectious Disease
# 1        1     1                    long covid       Infectious Disease
# 2        1     1          malaria therapeutics       Infectious Disease
# 3        1     2                        asthma                  Allergy
# 4        1     2   naegleria fowleri infection       Infectious Disease
# ..     ...   ...                           ...                      ...
# 367      4     5  plasmacytoid dendritic cells               Cell types
# 368      4     5          tuberculin skin test  Experimental techniques
# 369      4     6                           hiv       Infectious Disease
# 370      4     6                     influenza       Infectious Disease
# 371      4     6                 mycobacterium       Infectious Disease
#
#     test type selection
# 0           M        c1
# 1           M        c3
# 2           M        c2
# 3           M        c4
# 4           M       c11
# ..        ...       ...
# 367         M        c1
# 368         M       c15
# 369         M       c14
# 370         M        c3
# 371         M       c14
#
# [372 rows x 6 columns]

# %% [markdown]
# ## 3. Similarity computation using the Jaccard index

# %%
# Create sets of result ids for each combination
sets = most_likely.groupby('selection')['search term'].apply(set)

# Jaccard similarity between sets
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

# Calculate similarities
similarities = {}
for combi1 in sets.index:
    for combi2 in sets.index:
        if combi1 != combi2 and (combi2, combi1) not in similarities:
            similarity = jaccard_similarity(sets[combi1], sets[combi2])
            similarities[(combi1, combi2)] = similarity

print("\nJaccard similarities:")
for (combi1, combi2), similarity in similarities.items():
    print(f"Similarity between set_{combi1} and set_{combi2}: {similarity}")
# Out:
# Jaccard similarities:
# Similarity between set_c1 and set_c10: 0.92
# Similarity between set_c1 and set_c11: 0.76
# Similarity between set_c1 and set_c12: 0.72
# Similarity between set_c1 and set_c13: 0.84
# Similarity between set_c1 and set_c14: 0.92
# Similarity between set_c1 and set_c15: 0.84
# Similarity between set_c1 and set_c2: 0.88
# Similarity between set_c1 and set_c3: 0.84
# Similarity between set_c1 and set_c4: 0.92
# Similarity between set_c1 and set_c5: 0.88
# Similarity between set_c1 and set_c6: 0.52
# Similarity between set_c1 and set_c7: 0.72
# Similarity between set_c1 and set_c8: 0.84
# Similarity between set_c1 and set_c9: 0.84
# Similarity between set_c10 and set_c11: 0.75
# Similarity between set_c10 and set_c12: 0.7083333333333334
# Similarity between set_c10 and set_c13: 0.8333333333333334
# Similarity between set_c10 and set_c14: 0.9166666666666666
# Similarity between set_c10 and set_c15: 0.76
# Similarity between set_c10 and set_c2: 0.8
# Similarity between set_c10 and set_c3: 0.8333333333333334
# Similarity between set_c10 and set_c4: 0.9166666666666666
# Similarity between set_c10 and set_c5: 0.875
# Similarity between set_c10 and set_c6: 0.5
# Similarity between set_c10 and set_c7: 0.7083333333333334
# Similarity between set_c10 and set_c8: 0.8333333333333334
# Similarity between set_c10 and set_c9: 0.8333333333333334
# Similarity between set_c11 and set_c12: 0.85
# Similarity between set_c11 and set_c13: 0.8181818181818182
# Similarity between set_c11 and set_c14: 0.8260869565217391
# Similarity between set_c11 and set_c15: 0.7391304347826086
# Similarity between set_c11 and set_c2: 0.782608695652174
# Similarity between set_c11 and set_c3: 0.7391304347826086
# Similarity between set_c11 and set_c4: 0.75
# Similarity between set_c11 and set_c5: 0.7083333333333334
# Similarity between set_c11 and set_c6: 0.6842105263157895
# Similarity between set_c11 and set_c7: 0.85
# Similarity between set_c11 and set_c8: 0.7391304347826086
# Similarity between set_c11 and set_c9: 0.8181818181818182
# Similarity between set_c12 and set_c13: 0.8571428571428571
# Similarity between set_c12 and set_c14: 0.782608695652174
# Similarity between set_c12 and set_c15: 0.7727272727272727
# Similarity between set_c12 and set_c2: 0.8181818181818182
# Similarity between set_c12 and set_c3: 0.7727272727272727
# Similarity between set_c12 and set_c4: 0.782608695652174
# Similarity between set_c12 and set_c5: 0.8181818181818182
# Similarity between set_c12 and set_c6: 0.7222222222222222
# Similarity between set_c12 and set_c7: 0.8947368421052632
# Similarity between set_c12 and set_c8: 0.7727272727272727
# Similarity between set_c12 and set_c9: 0.8571428571428571
# Similarity between set_c13 and set_c14: 0.9130434782608695
# Similarity between set_c13 and set_c15: 0.8260869565217391
# Similarity between set_c13 and set_c2: 0.8695652173913043
# Similarity between set_c13 and set_c3: 0.9090909090909091
# Similarity between set_c13 and set_c4: 0.9130434782608695
# Similarity between set_c13 and set_c5: 0.8695652173913043
# Similarity between set_c13 and set_c6: 0.6190476190476191
# Similarity between set_c13 and set_c7: 0.8571428571428571
# Similarity between set_c13 and set_c8: 0.9090909090909091
# Similarity between set_c13 and set_c9: 0.9090909090909091
# Similarity between set_c14 and set_c15: 0.8333333333333334
# Similarity between set_c14 and set_c2: 0.875
# Similarity between set_c14 and set_c3: 0.9130434782608695
# Similarity between set_c14 and set_c4: 0.9166666666666666
# Similarity between set_c14 and set_c5: 0.875
# Similarity between set_c14 and set_c6: 0.5652173913043478
# Similarity between set_c14 and set_c7: 0.782608695652174
# Similarity between set_c14 and set_c8: 0.9130434782608695
# Similarity between set_c14 and set_c9: 0.9130434782608695
# Similarity between set_c15 and set_c2: 0.8695652173913043
# Similarity between set_c15 and set_c3: 0.8260869565217391
# Similarity between set_c15 and set_c4: 0.8333333333333334
# Similarity between set_c15 and set_c5: 0.7916666666666666
# Similarity between set_c15 and set_c6: 0.5454545454545454
# Similarity between set_c15 and set_c7: 0.6956521739130435
# Similarity between set_c15 and set_c8: 0.8260869565217391
# Similarity between set_c15 and set_c9: 0.9090909090909091
# Similarity between set_c2 and set_c3: 0.8695652173913043
# Similarity between set_c2 and set_c4: 0.875
# Similarity between set_c2 and set_c5: 0.8333333333333334
# Similarity between set_c2 and set_c6: 0.5909090909090909
# Similarity between set_c2 and set_c7: 0.8181818181818182
# Similarity between set_c2 and set_c8: 0.8695652173913043
# Similarity between set_c2 and set_c9: 0.8695652173913043
# Similarity between set_c3 and set_c4: 0.9130434782608695
# Similarity between set_c3 and set_c5: 0.8695652173913043
# Similarity between set_c3 and set_c6: 0.6190476190476191
# Similarity between set_c3 and set_c7: 0.7727272727272727
# Similarity between set_c3 and set_c8: 0.9090909090909091
# Similarity between set_c3 and set_c9: 0.9090909090909091
# Similarity between set_c4 and set_c5: 0.9565217391304348
# Similarity between set_c4 and set_c6: 0.5652173913043478
# Similarity between set_c4 and set_c7: 0.782608695652174
# Similarity between set_c4 and set_c8: 0.9130434782608695
# Similarity between set_c4 and set_c9: 0.9130434782608695
# Similarity between set_c5 and set_c6: 0.5909090909090909
# Similarity between set_c5 and set_c7: 0.8181818181818182
# Similarity between set_c5 and set_c8: 0.8695652173913043
# Similarity between set_c5 and set_c9: 0.8695652173913043
# Similarity between set_c6 and set_c7: 0.7222222222222222
# Similarity between set_c6 and set_c8: 0.5454545454545454
# Similarity between set_c6 and set_c9: 0.6190476190476191
# Similarity between set_c7 and set_c8: 0.7727272727272727
# Similarity between set_c7 and set_c9: 0.7727272727272727
# Similarity between set_c8 and set_c9: 0.9090909090909091
